# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya723/Movie-Recommender/blob/main/Movie_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
movies_df=pd.read_csv('/content/tmdb_5000_movies.csv')
credits_df=pd.read_csv('/content/tmdb_5000_credits.csv')

# %%
movies_df.sample(5)
# Out:
#          budget                                             genres  \
# 281   100000000  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 1839   25000000  [{"id": 27, "name": "Horror"}, {"id": 9648, "n...
# 3546          0                     [{"id": 35, "name": "Comedy"}]
# 4681          0                                                 []
# 3084   10000000                      [{"id": 18, "name": "Drama"}]
#
#                                 homepage      id  \
# 281     http://www.americangangster.net/    4982
# 1839                                 NaN    9286
# 3546                                 NaN   13173
# 4681  http://www.realityshowthefilm.com/  176074
# 3084                                 NaN   55720
#
#                                                keywords original_language  \
# 281   [{"id": 240, "name": "underdog"}, {"id": 577, ...                en
# 1839  [{"id": 1829, "name": "beheading"}, {"id": 373...                en
# ...

# %%
movies_df.shape
# Out:
# (4803, 20)

# %%
credits_df.sample(5)
# Out:
#       movie_id                                              title  \
# 262        120  The Lord of the Rings: The Fellowship of the Ring
# 2568      9100                                          The Craft
# 923       6877                                  Failure to Launch
# 417      16281                                          Creepshow
# 1241      1921                                     Sweet November
#
#                                                    cast  \
# 262   [{"cast_id": 28, "character": "Frodo Baggins",...
# 2568  [{"cast_id": 3, "character": "Sarah Bailey", "...
# 923   [{"cast_id": 4, "character": "Tripp", "credit_...
# 417   [{"cast_id": 9, "character": "Henry Northrup (...
# 1241  [{"cast_id": 15, "character": "Nelson", "credi...
#
#                                                    crew
# 262   [{"credit_id": "52fe421ac3a36847f80043fb", "de...
# 2568  [{"credit_id": "52fe44dcc3a36847f80ae457", "de...
# 923   [{"credit_id": "52fe4466c3a36847f8093caf", "de...
# ...

# %%
credits_df.shape
# Out:
# (4803, 4)

# %%
movies=movies_df.merge(credits_df,on='title')

# %%
movies.sample(5)
# Out:
#         budget                                             genres  \
# 2007         0  [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 4087   1000000                      [{"id": 18, "name": "Drama"}]
# 4347   1000000                     [{"id": 27, "name": "Horror"}]
# 2333         0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 1282  20000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                homepage     id  \
# 2007                                NaN  13579
# 4087  http://www.courageousthemovie.com  72213
# 4347                                NaN   9003
# 2333                                NaN  10934
# 1282                                NaN  10428
#
#                                                keywords original_language  \
# 2007                                                 []                en
# 4087  [{"id": 5905, "name": "father"}, {"id": 6150, ...                en
# ...

# %%
movies.shape
# Out:
# (4809, 23)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
movies['original_language'].value_counts()
# Out:
# original_language
# en    4510
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# ko      12
# cn      12
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# cs       2
# ta       2
# ro       2
# ar       2
# te       1
# hu       1
# xx       1
# af       1
# is       1
# tr       1
# vi       1
# pl       1
# nb       1
# ky       1
# no       1
# sl       1
# ps       1
# el       1
# Name: count, dtype: int64

# %%
#converting release time to datetime as they can't be object the datetime is always in strings
#This argument is crucial. If there are any values in 'release_date' that cannot be parsed into a datetime (e.g., malformed strings), errors='coerce' will turn them into NaT (Not a Time, pandas' version of NaN for datetimes), preventing errors and allowing the rest of the operation to proceed. NaT values will then correctly result in NaN in the 'release_year' column.
movies['release_date']=pd.to_datetime(movies['release_date'],errors='coerce')
movies['release_year']=movies['release_date'].dt.year
movies['release_year']
# Out:
# 0       2009.0
# 1       2007.0
# 2       2015.0
# 3       2012.0
# 4       2012.0
#          ...
# 4804    1992.0
# 4805    2011.0
# 4806    2013.0
# 4807    2012.0
# 4808    2005.0
# Name: release_year, Length: 4809, dtype: float64

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#Removing columns that are not necessary that is preprocessing the data and only including columns that are involved in making tags as we are making a content based
movies=movies[['genres','id','keywords','title','overview','cast','crew','release_year','popularity']]

# %%
movies.head()
# Out:
#                                               genres      id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
# ...

# %%
movies['release_year'].fillna(2015.0)
# Out:
# 0       2009.0
# 1       2007.0
# 2       2015.0
# 3       2012.0
# 4       2012.0
#          ...
# 4804    1992.0
# 4805    2011.0
# 4806    2013.0
# 4807    2012.0
# 4808    2005.0
# Name: release_year, Length: 4809, dtype: float64

# %%
#finding for missing data or duplicated data
movies.isnull().sum()
# Out:
# genres          0
# id              0
# keywords        0
# title           0
# overview        3
# cast            0
# crew            0
# release_year    1
# popularity      0
# dtype: int64

# %%
#the data contains 3 movies that doesn't have overviews therefore remove those missing values
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#we just want the name key values from the dictionary in form of a list
def convert(obj):
  l=[]
  for i in ast.literal_eval(obj):
    l.append(i['name'])
  return l

# %%
#before using convert function we first need to convert the genres from strings to list using ast module
movies['genres']=movies['genres'].apply(convert)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-266-2677918688.py in <cell line: 0>()
#       1 #before using convert function we first need to convert the genres from strings to list using ast module
# ----> 2 movies['genres']=movies['genres'].apply(convert)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
movies.iloc[0].keywords

# %%
#for cast same thing to be followed but we will just use top five cast
def converts(obj):
  if isinstance(obj, str):  # Check if the object is a string
      l = []
      count = 0
      for i in ast.literal_eval(obj):
          if count != 5:
              l.append(i['name'])
              count += 1
          else:
              break
      return l
  else: # if its not a string return as is.
    return obj

# %%
def converted(obj):
  if isinstance(obj, str):  # Check if obj is a string before using ast.literal_eval
    l = []
    for i in ast.literal_eval(obj):
      l.append(i['name'])
    return l
  else:  # If obj is not a string (e.g., a list), likely already processed
    # Return as is if it's already a list of strings
    if isinstance(obj, list) and all(isinstance(item, str) for item in obj):
      return obj
    # Handle other cases as needed
    return []  # or raise an exception if this scenario is unexpected
movies['keywords']=movies['keywords'].apply(converted)

# %%
movies['keywords'][0]

# %%
movies['cast']=movies['cast'].apply(converts)

# %%
movies['crew'][0]

# %%
def fetch_director(obj):
  if isinstance(obj, str):  # Check if obj is a string before using ast.literal_eval
    l = []
    for i in ast.literal_eval(obj):
      if i['job'] == 'Director':
        l.append(i['name'])
        break
    return l
  else:  # If obj is not a string (e.g., a list), likely already processed
    # Check if it's a list and contains the director's name
    if isinstance(obj, list) and len(obj) > 0 and isinstance(obj[0], dict):
        for item in obj:
          if item.get('job') == 'Director':
              return [item.get('name')]
    return obj # Return as is if it doesn't have the expected format

# %%
movies['crew']=movies['crew'].apply(fetch_director)

# %%
movies['overview'][0]

# %%
#it is a string and we will convert it to list for concatination with others
# Check if the element is not already a list before splitting
movies['overview'] = movies['overview'].apply(lambda x: x.split() if isinstance(x, str) else x)

# %%
# Remove spaces within column values to prevent inconsistencies in the recommender system
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()

# %%
#merging the columns to create a tag and converting them to string again to create a detailed paragraph for the mvoie tag
movies['tags']=movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']

# %%
movies['tags'][0]

# %%
new_df=movies[['id','title','tags']]

# %%
new_df['tags']=new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()

# %%
#stemming the data to reduce words ex ['loving','love'] to ['love','love']
import nltk
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
  y=[]
  for i in text.split():
    y.append(ps.stem(i))
  return " ".join(y)

# %%
new_df['tags']=new_df['tags'].apply(stem)

# %%
new_df['tags'][0]

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()

# %%
#Now our work is to recommend 5 similar movies to the user according to the movie or content he's watching
#To identitfy similarity we have to calculate the similarity between the tags of the movies
#therefore we will vectorise the text for that purpose and the techniques used is bag of words which is we will combine all the tags of all the mvoies
#then we will find the top 5000 words that has the most frequency from the concatenated tags
#for all the movies we will compare the rows that will have the frequencies of the top 5000 words for particular movies
#using CountVectorizer library for converting strings to token
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=5000,stop_words='english')

# %%
#toarray is used to convert the sparse matrix(from transform) to array
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors

# %%
#gives us the most frequent words
cv.get_feature_names_out()

# %%
#calculating cosine distances for finding the similarity between movies
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vectors)

# %%
similarity

# %%
new_df[new_df['title']=='Avatar'].index

# %%
#through enumerate function we could retain the original indexes of the movies even when they are reversed
#reversing the array to find the mostly similary movies on the top and then fetching top 5 similar movies from it
#using lambda function to check for the second value of tuple x (index,distance)
#1:6 is used to extarct top similar movies starting from 1st position as 0th position will have value 1 the highest as the movie have the distance with itself
sorted(list(enumerate(similarity[0])),reverse=True,key=lambda x:x[1])[1:6]

# %%
def recommend(movie):
  #find the indexes of the movies
  movie_index=new_df[new_df['title']==movie].index[0]
  distances=similarity[movie_index]
  movies_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

  for i in movies_list:
    print(new_df.iloc[i[0]].title)

# %%
recommend('The Dark Knight Rises')

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
